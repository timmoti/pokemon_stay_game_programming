# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game, and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# #### Package imports
#
# The pprint package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : amt of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
class Player():
    """
    Represents a player playing Pokemon Stay
    
    Attributes:
        playerid (int): a unique identifier
        player_name(str): a player's name
        time_played (float): indicates the time spent on the game by player in minutes
        player_pokemon (dict): a collection of the player's captured pokemon
        gyms_visited (list): a collection of the gyms a player has visited
    """
    def __init__(self):
        self.player_id = 0
        self.player_name = ""
        self.time_played = 0.0
        self.player_pokemon = {}
        self.gyms_visited = []
    
    def __str__(self):
        return "Player id: {}, Player Name: {}, Time Played: {}, Pokemon Captured: {}, Gyms Visited: {}".format(
            self.player_id, self.player_name, self.time_played, self.player_pokemon, self.gyms_visited)
    
    #def __getitem__(self, index):
        #return self.gyms_visited[index]
        
    #def __iter__(self):
        #return iter(self.gyms_visited)
        

player1 = Player()
player1.player_id = 1
player1.player_name = 'Tim'
player1.time_played = 10.0
print player1
# Out:
# Player id: 1, Player Name: Tim, Time Played: 10.0, Pokemon Captured: {}, Gyms Visited: []

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'sporcle.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
gym_locations = ['reddit.com', 'amazon.com', 'twitter.com', 'linkedin.com', 'ebay.com', 'netflix.com', 'sporcle.com', 'stackoverflow.com', 'github.com', 'quora.com']

player1.gyms_visited.append(gym_locations[0])
player1.gyms_visited.append(gym_locations[5])
pprint(player1.gyms_visited)
# Out:
# ['reddit.com', 'netflix.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
pokedex = {1: {'name': 'charmander', 'type': 'fire', 'hp': 39, 'attack': 52,'defense': 43,'special_attack': 60,'special_defense': 50,'speed': 65}, 
           2: {'name': 'squirtle', 'type': 'water', 'hp': 44, 'attack': 48,'defense': 65,'special_attack': 50,'special_defense': 64,'speed': 43},
           3: {'name': 'bulbasaur', 'type': 'poison', 'hp': 45, 'attack': 49,'defense': 49,'special_attack': 65,'special_defense': 65,'speed': 45}}
pprint(pokedex)
# Out:
# {1: {'attack': 52,
#      'defense': 43,
#      'hp': 39,
#      'name': 'charmander',
#      'special_attack': 60,
#      'special_defense': 50,
#      'speed': 65,
#      'type': 'fire'},
#  2: {'attack': 48,
#      'defense': 65,
#      'hp': 44,
#      'name': 'squirtle',
#      'special_attack': 50,
#      'special_defense': 64,
#      'speed': 43,
#      'type': 'water'},
#  3: {'attack': 49,
#      'defense': 49,
#      'hp': 45,
#      'name': 'bulbasaur',
#      'special_attack': 65,
#      'special_defense': 65,
#      'speed': 45,
#      'type': 'poison'}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
players = {}
player1_info = {'player_name': player1.player_name, 'time_played': player1.time_played, 
               'player_pokemon': player1.player_pokemon, 'gyms_visited': player1.gyms_visited}
players[player1.player_id] = player1_info
pprint(players)
# Out:
# {1: {'gyms_visited': ['reddit.com', 'netflix.com'],
#      'player_name': 'Tim',
#      'player_pokemon': {},
#      'time_played': 10.0}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'alcatraz'` and `'pacific_beach'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
player2 = Player()
player2.player_id = 2
player2.player_name = 'Christian'
player2.time_played = 4.0
player2.gyms_visited.append('alcatraz')
player2.gyms_visited.append('pacific beach')

player2_info = {'player_name': player2.player_name, 'time_played': player2.time_played, 
               'player_pokemon': player2.player_pokemon, 'gyms_visited': player2.gyms_visited}
players[player2.player_id] = player2_info
pprint(players)
# Out:
# {1: {'gyms_visited': ['reddit.com', 'netflix.com'],
#      'player_name': 'Tim',
#      'player_pokemon': {},
#      'time_played': 10.0},
#  2: {'gyms_visited': ['alcatraz', 'pacific beach'],
#      'player_name': 'Christian',
#      'player_pokemon': {},
#      'time_played': 4.0}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
player1.player_pokemon[2] = pokedex[2]
player2.player_pokemon[1] = pokedex[1]
player2.player_pokemon[3] = pokedex[3]

pprint(players)
# Out:
# {1: {'gyms_visited': ['reddit.com', 'netflix.com'],
#      'player_name': 'Tim',
#      'player_pokemon': {2: {'attack': 48,
#                             'defense': 65,
#                             'hp': 44,
#                             'name': 'squirtle',
#                             'special_attack': 50,
#                             'special_defense': 64,
#                             'speed': 43,
#                             'type': 'water'}},
#      'time_played': 10.0},
#  2: {'gyms_visited': ['alcatraz', 'pacific beach'],
#      'player_name': 'Christian',
#      'player_pokemon': {1: {'attack': 52,
#                             'defense': 43,
#                             'hp': 39,
#                             'name': 'charmander',
#                             'special_attack': 60,
#                             'special_defense': 50,
#                             'speed': 65,
#                             'type': 'fire'},
#                         3: {'attack': 49,
# ...

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
counter = 0
for gym in gym_locations:
    for player in players.keys():
        if gym in players[player]['gyms_visited']:
            print players[player]['player_name'], 'has visited', gym
        counter += 1
print counter
# Out:
# Tim has visited reddit.com
# Tim has visited netflix.com
# 20

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %% [markdown]
# ### Loops ran
# The loop ran through all 10 gym locations and through each player instance of which there were 2.
#
# The total number of loops run was thus **10 x 2 = 20**
#
# With N gyms and N players, the loop will thus run **10 x 10 = 100** times as a function of N
#
# ### Less loops
# By looping through the gym_visited list of each player instead of the whole gym_locations list, we are able to cut down the number of loops run.
#
# For our current example, the loop will run 2 times for each player instance and another 2 times for both gym locations  in the gyms_visited list of both players. The total number of loops ran is thus **2 x 2 = 4**.
#
# Thus a simple change in the structure of our nested for loop results in a more efficent way to achieve the same result.

# %%
#For a more efficient way of achieving the same result as above.
counter = 0
for player in players.keys():
    for gym in players[player]['gyms_visited']:
        if gym in gym_locations:
            print players[player]['player_name'], 'has visited', gym
        counter += 1
print counter
# Out:
# Tim has visited reddit.com
# Tim has visited netflix.com
# 4

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
def calculate_player_power(players, pokedex, player_id):
    """
    Calculates a player's power value defined as the sum of the base statistics of all their pokemon
    
    Args:
        players: A dictionary of players and their relevant pokemon game stats
        pokedex: A dictionary of available pokemon data and their relevant stats
        player_id: A player's id in the form of an integer and is a key in the players dictionary.
    
    Returns:
        The player's power value
    """
    power_value = 0
    for creature, levels in players[player_id]['player_pokemon'].items():
        creature_base_stats = pokedex[creature]['hp'] + pokedex[creature]['speed'] + pokedex[creature]['attack'] + pokedex[creature]['defense'] + pokedex[creature]['special_attack'] + pokedex[creature]['special_defense']
        power_value += creature_base_stats
    return power_value

print  players[1]['player_name'], "has", calculate_player_power(players, pokedex, 1),  "power."
print  players[2]['player_name'], "has", calculate_player_power(players, pokedex, 2),  "power."
# Out:
# Tim has 314 power.
# Christian has 627 power.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()
    pokedex = []
    raw_pd = raw_pd.replace('"', '').split("\n")
    split_data = []
    for row in raw_pd:
        split_data.append(row.split(','))
    for line in split_data:
        converted = []
        for item in line:
            if item.isdigit():
                converted.append(float(item))
            elif item == '' or None:
                converted.append(-1)
            else:
                converted.append(item)
        pokedex.append(converted)
f.close() 
print pokedex[0:3]
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'], [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0], [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]]

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()
    pokedex = [[float(item) if item.isdigit() else -1 if item == '' or None else item for item in line] for line in [row.split(',') for row in raw_pd.replace('"', '').split("\n")]]
f.close()
print pokedex[0:3]
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'], [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0], [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
import numpy as np
def make_pokedex_dict(pokedex):
    """
    Converts a parsed pokedex file into a dictionary while accounting for duplicate pokemon ids
    
    Args:
        pokedex: a parsed pokedex file
    
    Returns:
        A dictionary of pokemon ids as keys and their stats as key, value pairs in a nested dictionary
    """
    header = pokedex[0]
    header = header[1:]
    data = pokedex[1:]
    ids = []
    new_data = []
    for line in data:
        new_id = line[0]
        while new_id in ids:
            new_id = round(new_id + 0.1, 1)
        ids.append(new_id)
        line[0] = new_id
        new_data.append(line)
    pokedex_dict = {row[0]:{v:row[i+1] for i, v in enumerate(header)}for row in new_data}
    return pokedex_dict
    
pokedex_dict = make_pokedex_dict(pokedex)
pokedex_dict
# Out:
# {1.0: {'Attack': 49.0,
#   'Defense': 49.0,
#   'HP': 45.0,
#   'Name': 'Bulbasaur',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 45.0,
#   'Total': 318.0,
#   'Type': 'GrassPoison'},
#  2.0: {'Attack': 62.0,
#   'Defense': 63.0,
#   'HP': 60.0,
#   'Name': 'Ivysaur',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 60.0,
#   'Total': 405.0,
#   'Type': 'GrassPoison'},
#  3.0: {'Attack': 82.0,
#   'Defense': 83.0,
#   'HP': 80.0,
#   'Name': 'Venusaur',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 100.0,
#   'Speed': 80.0,
#   'Total': 525.0,
#   'Type': 'GrassPoison'},
#  3.1: {'Attack': 100.0,
#   'Defense': 123.0,
#   'HP': 80.0,
#   'Name': 'VenusaurMega Venusaur',
#   'SpecialAttack': 122.0,
#   'SpecialDefense': 120.0,
#   'Speed': 80.0,
#   'Total': 625.0,
#   'Type': 'GrassPoison'},
#  4.0: {'Attack': 52.0,
#   'Defense': 43.0,
#   'HP': 39.0,
#   'Name': 'Charmander',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 50.0,
# ...

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 25, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
def filtered_pokedex(pokedex_data, filter_options):
    """
    Returns a list of pokemon and their stats based on criteria set in filter_options
    
    Args:
        pokedex_data: a nested dictionary of pokemon creatures with id as keys and a dictionary of their stats as values.
        filter_options: a dictionary where keys are the stats to filter by. String values are filtered for exact match 
                        while number values are filtered for greater than or equal to parameter passed.
    
    Returns:
        a list of pokemon and their stats filtered by parameters specified in filter_options
        
    """
    filtered_list = []
    filter_options_keys = [key.lower().capitalize() for key in filter_options.keys()]
    
    
    #Handles case with 'Name' in filter options
    if 'Name' in filter_options_keys:
        for pokemon, stats in pokedex_data.items():
            if filter_options['Name'].lower().capitalize() == pokedex_data[pokemon]['Name']:
                filtered_list.append(stats)
        if filtered_list == []:
            print filter_options['Name'], 'not in pokedex.'
        else:
            for option, value in filter_options.items():
                if option == 'Type':
                    assert value == filtered_list[0]['Type'], 'Wrong Type for selected Pokemon'
                elif option != 'Name':
                    assert value <= filtered_list[0][option], '{} too high for selected Pokemon'.format(option)
                    
    #Handles case without 'Name' in filter options
    elif 'Type' in filter_options_keys:
        for pokemon, stats in pokedex_data.items():
            if filter_options['Type'].lower().capitalize() == pokedex_data[pokemon]['Type']:
                filtered_list.append(stats)
        filter_options.pop('Type')
        if filtered_list == []:
            print filter_options['Type'], 'not a valid Pokemon type.'
    else:
        for pokemon, stats in pokedex_data.items():
            if pokedex_data[pokemon][filter_options_keys[0]] >= filter_options[filter_options_keys[0]]:
                filtered_list.append(stats)
        filter_options.pop(filter_options_keys[0])
        

    for option, value in filter_options.items():
        for index, entry in reversed(list(enumerate(filtered_list))):
            if value > entry[option]:
                filtered_list.pop(index)
                
        
    return filtered_list

filtered_pokedex(pokedex_dict, {'Type': 'Electric', 'Attack': 50, 'Defense': 50, 'Speed': 100})
# Out:
# [{'Attack': 90.0,
#   'Defense': 55.0,
#   'HP': 60.0,
#   'Name': 'Raichu',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 80.0,
#   'Speed': 110.0,
#   'Total': 485.0,
#   'Type': 'Electric'},
#  {'Attack': 50.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Electrode',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 140.0,
#   'Total': 480.0,
#   'Type': 'Electric'},
#  {'Attack': 83.0,
#   'Defense': 57.0,
#   'HP': 65.0,
#   'Name': 'Electabuzz',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 85.0,
#   'Speed': 105.0,
#   'Total': 490.0,
#   'Type': 'Electric'},
#  {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Jolteon',
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 95.0,
#   'Speed': 130.0,
#   'Total': 525.0,
#   'Type': 'Electric'},
#  {'Attack': 85.0,
#   'Defense': 75.0,
#   'HP': 90.0,
#   'Name': 'Raikou',
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 100.0,
#   'Speed': 115.0,
#   'Total': 580.0,
# ...

# %% [markdown]
# ## 11. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 11.1
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %%
import numpy as np

total_list = [pokedex_dict[character]['Total'] for character in pokedex_dict]
population_mean = np.mean(total_list)
standard_deviation = np.std(total_list)

print 'Population Mean:', population_mean 
print 'Standard Deviation:', standard_deviation
# Out:
# Population Mean: 435.1275
# Standard Deviation: 119.962020005

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 11.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %%
upper_limit = population_mean + 3*standard_deviation
print 'A character is considered overpowered if its Total attribute is greater than', upper_limit

overpowered_characters = {}
for character in pokedex_dict:
    if pokedex_dict[character]['Total'] > upper_limit:
        overpowered_characters[character] = pokedex_dict[character]['Name']
print 'Overpowered characters:', overpowered_characters,
# Out:
# A character is considered overpowered if its Total attribute is greater than 795.013560016
# Overpowered characters: {150.1: 'MewtwoMega Mewtwo X'}

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 12. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.

# %%
def probability_pokemon(pokemon_id):
    """
    Creates a probability of finding a pokemon in a gym
    
    Args:
        pokemon_id: A float or integer linked to a pokemon in a pokedex dictionary
        
    Returns:
        A probability value, probability_i, for the pokemon with the specified id
    """
    sorted_total_list = sorted([(stats['Total'], character) for character, stats in pokedex_dict.items()])
    sorted_probabilities_list = sorted([stats['Total']/sum(total_list) for stats in pokedex_dict.values()], reverse=True)
    total_probabilities_dict = {character[0][1]: character[1] for character in zip(sorted_total_list, sorted_probabilities_list)}
    probability_i = total_probabilities_dict[pokemon_id]
    
    return probability_i

probability_pokemon(150.1)
# Out:
# 0.0005170898185014737
